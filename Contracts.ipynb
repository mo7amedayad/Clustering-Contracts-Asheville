# %% [markdown]
# ##### This is data from the City of Asheville regarding Construction and Repair contracts from as early as Jan 4, 2010,up to February 24, 2022. Last updated 2/27/2022.

# %% [markdown]
# **https://www.kaggle.com/trobacker/asheville-nc-construction-and-repair-contracts**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize': [9, 9]}, font_scale=1.5)

# %%
df_1 = pd.read_csv('Munis_Contracts_Asheville.csv')

# %%
df_1
# Out:
#       OBJECTID  contract_number  \
# 0            1         91800268
# 1            2         91500051
# 2            3         91000424
# 3            4         91000588
# 4            5         91100175
# ...        ...              ...
# 4249      4250         91400187
# 4250      4251         92200067
# 4251      4252         91900167
# 4252      4253         92000092
# 4253      4254         91100334
#
#                                    contract_description contract_status  \
# 0     CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1     DISASTER AND ENS REGISTRATION SERVICES        ...          CLOSED
# 2     WEED & SEED CONTRACTOR                        ...          CLOSED
# 3     WEED & SEED RESOURCE PROVIDER                 ...          CLOSED
# 4     CARWASH FOR POLICE VEHICLE FY 2010-2011       ...          CLOSED
# ...                                                 ...             ...
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4254 entries, 0 to 4253
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBJECTID              4254 non-null   int64
#  1   contract_number       4254 non-null   int64
#  2   contract_description  4254 non-null   object
#  3   contract_status       4254 non-null   object
#  4   contract_type         4254 non-null   object
#  5   contract_subtype      385 non-null    object
#  6   last_modified         4254 non-null   object
#  7   original_amount       4244 non-null   float64
#  8   revised_amount        4244 non-null   float64
#  9   vendor_id             4254 non-null   int64
#  10  vendor_name           4252 non-null   object
#  11  objectid_1            4254 non-null   int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 398.9+ KB

# %%
df_1.describe(percentiles=[.10,.35,.60,.80,.90,.95,.99])
# Out:
#           OBJECTID  contract_number  original_amount  revised_amount  \
# count  4254.000000     4.254000e+03     4.244000e+03    4.244000e+03
# mean   2127.500000     9.157476e+07     1.090390e+05    1.413786e+05
# std    1228.168352     3.955198e+05     6.840293e+05    1.111881e+06
# min       1.000000     9.100002e+07     0.000000e+00    0.000000e+00
# 10%     426.300000     9.110011e+07     1.500000e+03    1.296500e+03
# 35%    1489.550000     9.130024e+07     8.500000e+03    9.034378e+03
# 50%    2127.500000     9.160016e+07     1.500000e+04    1.652944e+04
# 60%    2552.800000     9.170041e+07     2.277680e+04    2.490518e+04
# 80%    3403.400000     9.200025e+07     6.000000e+04    7.343200e+04
# 90%    3828.700000     9.210031e+07     1.659746e+05    1.978172e+05
# 95%    4041.350000     9.220010e+07     3.862976e+05    4.549465e+05
# 99%    4211.470000     9.220029e+07     1.869164e+06    1.978205e+06
# max    4254.000000     9.220033e+07     3.492800e+07    4.016720e+07
#
# ...

# %%
df_1.drop(['contract_subtype'], axis=1, inplace=True)
df_1.head(10)
# Out:
#    OBJECTID  contract_number  \
# 0         1         91800268
# 1         2         91500051
# 2         3         91000424
# 3         4         91000588
# 4         5         91100175
# 5         6         91000322
# 6         7         91100099
# 7         8         91900109
# 8         9         92100429
# 9        10         91600212
#
#                                 contract_description contract_status  \
# 0  CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1  DISASTER AND ENS REGISTRATION SERVICES        ...          CLOSED
# 2  WEED & SEED CONTRACTOR                        ...          CLOSED
# 3  WEED & SEED RESOURCE PROVIDER                 ...          CLOSED
# 4  CARWASH FOR POLICE VEHICLE FY 2010-2011       ...          CLOSED
# 5  PSYCHOLOGICAL TESTING FOR APD EMPLOYEES       ...          CLOSED
# 6  SIGN FOR STATION 12                           ...          CLOSED
# 7  SWANNANOA 1: PRELIM CORRIDOR DESIGN .         ...          POSTED
# ...

# %%
df_1.corr()
# Out:
#                  OBJECTID  contract_number  original_amount  revised_amount  \
# OBJECTID         1.000000        -0.000534        -0.027685       -0.014512
# contract_number -0.000534         1.000000         0.052435        0.040443
# original_amount -0.027685         0.052435         1.000000        0.724854
# revised_amount  -0.014512         0.040443         0.724854        1.000000
# vendor_id       -0.009570         0.441734         0.003074        0.013086
# objectid_1       1.000000        -0.000534        -0.027685       -0.014512
#
#                  vendor_id  objectid_1
# OBJECTID         -0.009570    1.000000
# contract_number   0.441734   -0.000534
# original_amount   0.003074   -0.027685
# revised_amount    0.013086   -0.014512
# vendor_id         1.000000   -0.009570
# objectid_1       -0.009570    1.000000

# %%
df_1.describe(percentiles=[.10,.35,.60,.80,.90,.95,.99])
# Out:
#           OBJECTID  contract_number  original_amount  revised_amount  \
# count  4254.000000     4.254000e+03     4.244000e+03    4.244000e+03
# mean   2127.500000     9.157476e+07     1.090390e+05    1.413786e+05
# std    1228.168352     3.955198e+05     6.840293e+05    1.111881e+06
# min       1.000000     9.100002e+07     0.000000e+00    0.000000e+00
# 10%     426.300000     9.110011e+07     1.500000e+03    1.296500e+03
# 35%    1489.550000     9.130024e+07     8.500000e+03    9.034378e+03
# 50%    2127.500000     9.160016e+07     1.500000e+04    1.652944e+04
# 60%    2552.800000     9.170041e+07     2.277680e+04    2.490518e+04
# 80%    3403.400000     9.200025e+07     6.000000e+04    7.343200e+04
# 90%    3828.700000     9.210031e+07     1.659746e+05    1.978172e+05
# 95%    4041.350000     9.220010e+07     3.862976e+05    4.549465e+05
# 99%    4211.470000     9.220029e+07     1.869164e+06    1.978205e+06
# max    4254.000000     9.220033e+07     3.492800e+07    4.016720e+07
#
# ...

# %%
df_1.columns
# Out:
# Index(['OBJECTID', 'contract_number', 'contract_description',
#        'contract_status', 'contract_type', 'last_modified', 'original_amount',
#        'revised_amount', 'vendor_id', 'vendor_name', 'objectid_1'],
#       dtype='object')

# %%
for col in ['contract_description', 'contract_status','contract_type', 'last_modified','vendor_name']:
    print(f'-------{col}-------')
    print(df_1[col].unique())
    print('________________________'*3)
# Out:
# -------contract_description-------
# ['CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19     '
#  'DISASTER AND ENS REGISTRATION SERVICES            '
#  'WEED & SEED CONTRACTOR                            ' ...
#  'POLICE VEHICLE EQUIPMENT INSTALLATION AND REPAIR  '
#  'STRUCTURAL STEEL/FIRE RATED CEILING - CH GARAGE   '
#  'HAYNES ELECTRIC                                   ']
# ________________________________________________________________________
# -------contract_status-------
# ['CLOSED' 'POSTED' 'CREATED' '4 ' '0 ']
# ________________________________________________________________________
# -------contract_type-------
# ['GS   (GEN SERV)' 'GENERAL' 'PRO  (PRO SERVIC)' 'CON  (CONSTUCT/R)'
#  'ENT  (ENTERTAIN)' 'RNT  (EQUIP RENT)' 'HUD (GEN SERV-HUD)'
#  'INS  (INSTRUCTOR)' "LW   (DON'T USE)" 'LS   (LEASE SVCS)'
#  'RISK - HR / INS' 'IT/TECH']
# ________________________________________________________________________
# -------last_modified-------
# ...

# %%
for col in ['contract_description', 'contract_status','contract_type', 'last_modified','vendor_name']:
    print(f'-------{col}-------')
    print(df_1[col].value_counts())
    print('________________________'*3)
# Out:
# -------contract_description-------
#                                                       80
# BC 10 STAGE CREW                                      18
# POSTAGE WATER RESOURCES                               16
# WEED & SEED RESOURCE PROVIDER                         15
# ATHLETIC OFFICIAL                                     10
#                                                       ..
# CLOGGING CLASSES                                       1
# INSTALL CONDUIT FOR GARAGE SIGNS                       1
# HVAC DUCT CLEANING IN ARENA                            1
# ASSISTANCE FOR EMPLOYEES EXPERICANCING PROBLEMS        1
# TEMPORARY STAFFING SERVICE FOR DEPARTMENT              1
# Name: contract_description, Length: 3880, dtype: int64
# ________________________________________________________________________
# -------contract_status-------
# CLOSED     3560
# POSTED      646
# CREATED      40
# 4             7
# 0             1
# Name: contract_status, dtype: int64
# ...

# %%
df_2 = pd.read_csv('vendors_ncasheville.csv')
df_2
# Out:
#       OBJECTID  objectid_1                        vendor_name vendor_city  \
# 0            1           1              COA ONETRAVEL.COM AIR   LAS VEGAS
# 1            2           2    GUILFORD PETROLEUM SERVICES INC   LEICESTER
# 2            3           3                  CUMULUS KNOXVILLE   KNOXVILLE
# 3            4           4    ECKERD YOUTH ALTERNATIVES, INC.  CLEARWATER
# 4            5           5      MOUNTAIN VETERINARY PATHOLOGY   ASHEVILLE
# ...        ...         ...                                ...         ...
# 5762      5763        5763                  NORTHERN FIREARMS      WALKER
# 5763      5764        5764                          HVAC, INC     BRISTOL
# 5764      5765        5765         TIME MANUFACTURING COMPANY        WACO
# 5765      5766        5766      COMPETITIVE EDGE OUTDOORS LLC   ASHEVILLE
# 5766      5767        5767  ROBINSON & COMPANY PAINTING, INC.   ASHEVILLE
#
#      vendor_state vendor_zip_code  vendor_id
# ...

# %%
df_1.columns
# Out:
# Index(['OBJECTID', 'contract_number', 'contract_description',
#        'contract_status', 'contract_type', 'last_modified', 'original_amount',
#        'revised_amount', 'vendor_id', 'vendor_name', 'objectid_1'],
#       dtype='object')

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5767 entries, 0 to 5766
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OBJECTID         5767 non-null   int64
#  1   objectid_1       5767 non-null   int64
#  2   vendor_name      5767 non-null   object
#  3   vendor_city      5746 non-null   object
#  4   vendor_state     5751 non-null   object
#  5   vendor_zip_code  5745 non-null   object
#  6   vendor_id        5767 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 315.5+ KB

# %%
df=pd.merge(df_1,df_2,on='vendor_id',how='inner')

# %%
df
# Out:
#       OBJECTID_x  contract_number  \
# 0              1         91800268
# 1            113         91200047
# 2            130         92000324
# 3            138         91500063
# 4            179         92200288
# ...          ...              ...
# 3143        4192         92100102
# 3144        4210         91700090
# 3145        4211         91900121
# 3146        4229         91800351
# 3147        4233         91900207
#
#                                    contract_description contract_status  \
# 0     CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1     CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 2     CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 3     POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4     INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
# ...                                                 ...             ...
# ...

# %%
check_column1=pd.DataFrame(df_1['vendor_name'].unique())
check_column2=pd.DataFrame(df_2['vendor_name'].unique())
check_column1.equals(check_column2)
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3148 entries, 0 to 3147
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBJECTID_x            3148 non-null   int64
#  1   contract_number       3148 non-null   int64
#  2   contract_description  3148 non-null   object
#  3   contract_status       3148 non-null   object
#  4   contract_type         3148 non-null   object
#  5   last_modified         3148 non-null   object
#  6   original_amount       3139 non-null   float64
#  7   revised_amount        3139 non-null   float64
#  8   vendor_id             3148 non-null   int64
#  9   vendor_name_x         3148 non-null   object
#  10  objectid_1_x          3148 non-null   int64
#  11  OBJECTID_y            3148 non-null   int64
#  12  objectid_1_y          3148 non-null   int64
#  13  vendor_name_y         3148 non-null   object
#  14  vendor_city           3148 non-null   object
# ...

# %%
df.describe()
# Out:
#         OBJECTID_x  contract_number  original_amount  revised_amount  \
# count  3148.000000     3.148000e+03     3.139000e+03    3.139000e+03
# mean   2126.786849     9.167015e+07     1.250824e+05    1.693642e+05
# std    1230.509698     3.693666e+05     7.658549e+05    1.275070e+06
# min       1.000000     9.100002e+07     0.000000e+00    0.000000e+00
# 25%    1057.500000     9.130031e+07     7.329380e+03    7.591930e+03
# 50%    2113.500000     9.170036e+07     1.877500e+04    2.034700e+04
# 75%    3206.250000     9.200022e+07     5.000000e+04    6.097050e+04
# max    4254.000000     9.220033e+07     3.492800e+07    4.016720e+07
#
#           vendor_id  objectid_1_x   OBJECTID_y  objectid_1_y
# count   3148.000000   3148.000000  3148.000000   3148.000000
# mean   13211.503812   2125.786849  2789.079098   2789.079098
# std    11222.822938   1230.509698  1599.163128   1599.163128
# min       21.000000      0.000000     4.000000      4.000000
# ...

# %%
df[['vendor_name_x','vendor_name_y']].value_counts()
# Out:
# vendor_name_x                                      vendor_name_y
# M B HAYNES CORPORATION                             M B HAYNES CORPORATION                               67
# BUNCOMBE COUNTY FINANCE DEPT                       BUNCOMBE COUNTY FINANCE DEPT                         55
# MAIL MANAGEMENT SERVICES                           MAIL MANAGEMENT SERVICES                             44
# WOOD ENVIRONMENT & INFRASTRUCTURE SOLUTIONS, INC.  WOOD ENVIRONMENT & INFRASTRUCTURE SOLUTIONS, INC.    40
# WILLIAM A STEWART SUPERIOR PAINTING INC.           WILLIAM A STEWART SUPERIOR PAINTING INC.             34
#                                                                                                         ..
# IPS GROUP INC                                      IPS GROUP INC                                         1
# IRENE MORRIS                                       IRENE MORRIS                                          1
# ...

# %%
def Dif_amount(Amount_difference):
    subtract_amount=Amount_difference['original_amount']-Amount_difference['revised_amount']
    return subtract_amount

# %%
df['Amount_difference']=df.apply(Dif_amount,axis=1)

# %%
df
# Out:
#       OBJECTID_x  contract_number  \
# 0              1         91800268
# 1            113         91200047
# 2            130         92000324
# 3            138         91500063
# 4            179         92200288
# ...          ...              ...
# 3143        4192         92100102
# 3144        4210         91700090
# 3145        4211         91900121
# 3146        4229         91800351
# 3147        4233         91900207
#
#                                    contract_description contract_status  \
# 0     CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1     CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 2     CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 3     POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4     INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
# ...                                                 ...             ...
# ...

# %%
df['Amount_difference'].describe()
# Out:
# count    3.139000e+03
# mean    -4.428188e+04
# std      8.988925e+05
# min     -3.412919e+07
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.187500e+01
# max      1.868115e+06
# Name: Amount_difference, dtype: float64

# %%
df.set_index('OBJECTID_x')
# Out:
#             contract_number  \
# OBJECTID_x
# 1                  91800268
# 113                91200047
# 130                92000324
# 138                91500063
# 179                92200288
# ...                     ...
# 4192               92100102
# 4210               91700090
# 4211               91900121
# 4229               91800351
# 4233               91900207
#
#                                          contract_description contract_status  \
# OBJECTID_x
# 1           CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 113         CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 130         CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 138         POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 179         INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
# ...                                                       ...             ...
# ...

# %%
df['last_modified'] = pd.to_datetime(df['last_modified'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
df
# Out:
#       OBJECTID_x  contract_number  \
# 0              1         91800268
# 1            113         91200047
# 2            130         92000324
# 3            138         91500063
# 4            179         92200288
# ...          ...              ...
# 3143        4192         92100102
# 3144        4210         91700090
# 3145        4211         91900121
# 3146        4229         91800351
# 3147        4233         91900207
#
#                                    contract_description contract_status  \
# 0     CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1     CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 2     CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 3     POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4     INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
# ...                                                 ...             ...
# ...

# %%
df['Year'] = df['last_modified'].dt.year

# %%
df['month'] = df['last_modified'].dt.month
df['hour'] = df['last_modified'].dt.hour
df['week_day'] = df['last_modified'].dt.day_name()
df
# Out:
#       OBJECTID_x  contract_number  \
# 0              1         91800268
# 1            113         91200047
# 2            130         92000324
# 3            138         91500063
# 4            179         92200288
# ...          ...              ...
# 3143        4192         92100102
# 3144        4210         91700090
# 3145        4211         91900121
# 3146        4229         91800351
# 3147        4233         91900207
#
#                                    contract_description contract_status  \
# 0     CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1     CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 2     CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 3     POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4     INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
# ...                                                 ...             ...
# ...

# %%
df.loc[:,df.nunique()==1].columns
# Out:
# Index(['hour'], dtype='object')

# %%
def map_months(x):
    if x in [12, 1, 2]:
        return 'Winter'
    elif x in [3, 4, 5]:
        return 'Spring'
    elif x in [6, 7, 8]:
        return 'Summer'
    elif x in [9, 10, 11]:
        return 'Autumn'

df['Season'] = df['month'].apply(map_months)
df.head()
# Out:
#    OBJECTID_x  contract_number  \
# 0           1         91800268
# 1         113         91200047
# 2         130         92000324
# 3         138         91500063
# 4         179         92200288
#
#                                 contract_description contract_status  \
# 0  CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1  CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 2  CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 3  POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4  INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
#
#      contract_type             last_modified  original_amount  revised_amount  \
# 0  GS   (GEN SERV) 2019-04-02 00:00:00+00:00        1037830.0       877933.38
# 1  GS   (GEN SERV) 2013-01-29 00:00:00+00:00          39902.0        38631.55
# 2  GS   (GEN SERV) 2021-04-22 00:00:00+00:00          45237.0        43970.86
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       OBJECTID_x  contract_number  \
# 0              1         91800268
# 1            113         91200047
# 2            130         92000324
# 3            138         91500063
# 4            179         92200288
# ...          ...              ...
# 3143        4192         92100102
# 3144        4210         91700090
# 3145        4211         91900121
# 3146        4229         91800351
# 3147        4233         91900207
#
#                                    contract_description contract_status  \
# 0     CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1     CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 2     CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 3     POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4     INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
# ...                                                 ...             ...
# ...

# %%
for col in ['contract_description', 'contract_status','contract_type', 'last_modified','vendor_name_x',
            'vendor_state','Season','week_day','vendor_city']:
    print(f'-------{col}-------')
    print(df[col].value_counts())
    print('________________________'*3)
# Out:
# -------contract_description-------
#                                                       36
# POSTAGE WATER RESOURCES                               16
# WEED & SEED RESOURCE PROVIDER                          6
# ANNUAL COST TO MAINTAIN FLASHING LIGHT CROSSING        5
# MASTER CONTRACT RENTAL EQUIPMENT                       4
#                                                       ..
# GENERATOR REPAIR AT NORTH FOR WATER PLANT              1
# ENGINEERING-INNSBROOK/MAPLEWOOD/MTN CREST/PATTON C     1
# SECURITY FOR RAMADA INN/ ECONO LODGE NON - CS          1
# AMARANTH APARTMENTS FY18-19 AMARANTH HOMESTEAD LLC     1
# 298-RFP02102020 DIGITAL PUBLIC INFO DISPLAY SIGNS/     1
# Name: contract_description, Length: 2947, dtype: int64
# ________________________________________________________________________
# -------contract_status-------
# CLOSED     2526
# POSTED      582
# CREATED      33
# 4             7
# Name: contract_status, dtype: int64
# ...

# %%
for x in df['contract_description']:
    print(x)
    print (20*'_')
# Out:
# CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19
# ____________________
# CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT
# ____________________
# CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICES
# ____________________
# POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15
# ____________________
# INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GRANT
# ____________________
# RADIO DISPATCHERS PER ADD. 2 TO INTERGOV'T AGRMT
# ____________________
# CONTINUATION OF SERVICES FOR FY 2013-14
# ____________________
# CRIME STOPPERS - CONTINUATION OF SERVICES FOR FY19
# ____________________
# BUNCOMBE COUNTY JOINT UTILITY ENERGY INNOVATION
# ____________________
# POLICE ID BUREAU- CONTINUATION OF SERV FY 2015-16
# ____________________
# 3 DISPATCHERS FOR FY 19-20 CONTINUATION OF SERVICE
# ____________________
# CJIS/CDE - CONTINUATION OF SERVICES FY 17
# ____________________
# RADIO DISPATCHERS PER ADD. 2 TO INTERGOVT AGRMT
# ____________________
# PROPERTY TAX BILLING FEE
# ____________________
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID_x', 'contract_number', 'contract_description',
#        'contract_status', 'contract_type', 'last_modified', 'original_amount',
#        'revised_amount', 'vendor_id', 'vendor_name_x', 'objectid_1_x',
#        'OBJECTID_y', 'objectid_1_y', 'vendor_name_y', 'vendor_city',
#        'vendor_state', 'vendor_zip_code', 'Amount_difference', 'Year', 'month',
#        'hour', 'week_day', 'Season'],
#       dtype='object')

# %%
df.drop(['vendor_name_y','OBJECTID_y','objectid_1_x','hour','objectid_1_y','OBJECTID_x'], axis=1, inplace=True)

# %%
df.select_dtypes(exclude=([object])).sample(7)
# Out:
#       contract_number             last_modified  original_amount  \
# 49           91300049 2014-05-21 00:00:00+00:00        875939.00
# 2736         91100610 2013-01-30 00:00:00+00:00          1500.00
# 1728         91500309 2016-06-21 00:00:00+00:00         85500.00
# 429          92000406 2020-06-25 00:00:00+00:00          3347.98
# 2555         91200119 2012-06-26 00:00:00+00:00          5800.00
# 1300         92100465 2021-08-20 00:00:00+00:00         14000.00
# 1904         91200301 2012-05-09 00:00:00+00:00         18960.00
#
#       revised_amount  vendor_id  Amount_difference  Year  month
# 49         725939.00        416          150000.00  2014      5
# 2736            0.00        909            1500.00  2013      1
# 1728        85500.00      17106               0.00  2016      6
# 429          3347.98       6812               0.00  2020      6
# 2555         6784.71       9091            -984.71  2012      6
# ...

# %%
df.select_dtypes(include=([object])).head()
# Out:
#                                 contract_description contract_status  \
# 0  CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...          CLOSED
# 1  CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...          CLOSED
# 2  CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...          CLOSED
# 3  POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4  INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
#
#      contract_type                 vendor_name_x vendor_city vendor_state  \
# 0  GS   (GEN SERV)  BUNCOMBE COUNTY FINANCE DEPT   ASHEVILLE           NC
# 1  GS   (GEN SERV)  BUNCOMBE COUNTY FINANCE DEPT   ASHEVILLE           NC
# 2  GS   (GEN SERV)  BUNCOMBE COUNTY FINANCE DEPT   ASHEVILLE           NC
# 3          GENERAL  BUNCOMBE COUNTY FINANCE DEPT   ASHEVILLE           NC
# 4  GS   (GEN SERV)  BUNCOMBE COUNTY FINANCE DEPT   ASHEVILLE           NC
#
#   vendor_zip_code   week_day  Season
# 0           28801    Tuesday  Spring
# ...

# %%
df
# Out:
#       contract_number                               contract_description  \
# 0            91800268  CJIS/CDE - CONTINUATION OF SERVICES FOR FY 19 ...
# 1            91200047  CRIMESTOPPERS FY'2012-INTERLOCAL AGREEMENT    ...
# 2            92000324  CRIMESTOPPERS FY 19-20 CONTINUATION OF SERVICE...
# 3            91500063  POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...
# 4            92200288  INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...
# ...               ...                                                ...
# 3143         92100102  STATION CHECK - CLOSE                         ...
# 3144         91700090  WELLINGTON STREET WATERSHED AND STORMWATER STU...
# 3145         91900121  FY2018 - 2019 FINANCIAL AUDIT                 ...
# 3146         91800351  HAZMAT: TRAINING CLASS FOR CARGO TANK EM      ...
# 3147         91900207  WEBSITE AND TM ENGAGEMENT FOR USCC            ...
#
#      contract_status      contract_type             last_modified  \
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### what's tha vendor name & vendor city & Amount difference& contract_description & last Year modified & contract type & contract status Who paid amount the biggest?

# %%
df.loc[:,['original_amount']].max()
# Out:
# original_amount    34928000.0
# dtype: float64

# %%
df[(df['original_amount'])==df['original_amount'].max()][['vendor_name_x','vendor_city','Amount_difference','contract_description','Year','contract_type','contract_status']].T
# Out:
#                                                                    2105
# vendor_name_x                                   PHILLIPS & JORDAN, INC.
# vendor_city                                                   KNOXVILLE
# Amount_difference                                            -5239200.0
# contract_description  NORTH FORK SPILLWAY & EMBANKMENT IMPROVEMENTS ...
# Year                                                               2021
# contract_type                                         CON  (CONSTUCT/R)
# contract_status                                                  POSTED

# %% [markdown]
# #### What is the average original amount in years?

# %%
df.groupby('Year').mean()['original_amount']
# Out:
# Year
# 2010     36000.673077
# 2011     34601.213304
# 2012     35694.117799
# 2013     55636.303533
# 2014     98084.258067
# 2015     73650.445215
# 2016    126706.450375
# 2017     64956.355187
# 2018    121487.095269
# 2019    146886.241908
# 2020     98515.455382
# 2021    210129.583088
# 2022    208244.010469
# Name: original_amount, dtype: float64

# %%
df['contract_status'].value_counts()
# Out:
# CLOSED     2526
# POSTED      582
# CREATED      33
# 4             7
# Name: contract_status, dtype: int64

# %% [markdown]
# #### What is the most contract status in 2022

# %%
df[(df['Year']==df['Year'].max())][['contract_status']].mode()
# Out:
#   contract_status
# 0          POSTED

# %% [markdown]
# #### Analyze a descriptive analysis of the status of contract with the original amount

# %%
df.groupby('contract_status').describe()['original_amount'].T
# Out:
# contract_status             4         CLOSED        CREATED        POSTED
# count                 7.000000  2.525000e+03      27.000000  5.800000e+02
# mean              56304.152857  9.688433e+04   58247.696296  2.517823e+05
# std               76521.769014  3.601898e+05  165067.596244  1.610025e+06
# min                3438.620000  0.000000e+00     250.000000  0.000000e+00
# 25%                7163.240000  7.000000e+03    6193.955000  1.000000e+04
# 50%               12500.000000  1.700000e+04   20000.000000  2.900000e+04
# 75%               75000.000000  4.468700e+04   33103.310000  8.992475e+04
# max              213863.970000  6.901571e+06  867774.000000  3.492800e+07

# %%
df[['contract_status']].mode()
# Out:
#   contract_status
# 0          CLOSED

# %%
df[(df['contract_status'])==df['contract_status']].mode()[:1:]
# Out:
#    contract_number                               contract_description  \
# 0         91900108                                                ...
#
#   contract_status    contract_type last_modified  original_amount  \
# 0          CLOSED  GS   (GEN SERV)    2021-08-20          10000.0
#
#    revised_amount  vendor_id           vendor_name_x vendor_city vendor_state  \
# 0             0.0     1188.0  M B HAYNES CORPORATION   ASHEVILLE           NC
#
#   vendor_zip_code  Amount_difference    Year  month week_day  Season
# 0           28801                0.0  2021.0    6.0   Friday  Summer

# %% [markdown]
# #### What is the most contract type in 2022

# %%
df[(df['Year']==df['Year'].max())][['contract_type']].mode()
# Out:
#      contract_type
# 0  GS   (GEN SERV)

# %%
df[(df['contract_type'])==df['contract_type']].mode()[:1:]
# Out:
#    contract_number                               contract_description  \
# 0         91900108                                                ...
#
#   contract_status    contract_type last_modified  original_amount  \
# 0          CLOSED  GS   (GEN SERV)    2021-08-20          10000.0
#
#    revised_amount  vendor_id           vendor_name_x vendor_city vendor_state  \
# 0             0.0     1188.0  M B HAYNES CORPORATION   ASHEVILLE           NC
#
#   vendor_zip_code  Amount_difference    Year  month week_day  Season
# 0           28801                0.0  2021.0    6.0   Friday  Summer

# %% [markdown]
# #### How much is the total original amount with the status of contract in years

# %%
new_df2=pd.pivot_table(data=df, values ='original_amount',columns ='contract_status',index ='Year')
new_df2
# Out:
# contract_status         4          CLOSED       CREATED         POSTED
# Year
# 2010                   NaN   36000.673077           NaN            NaN
# 2011                   NaN   34601.213304           NaN            NaN
# 2012                   NaN   35694.117799           NaN            NaN
# 2013                   NaN   55636.303533           NaN            NaN
# 2014                   NaN   98084.258067           NaN            NaN
# 2015                   NaN   73650.445215           NaN            NaN
# 2016                   NaN  126706.450375           NaN            NaN
# 2017                   NaN   64956.355187           NaN            NaN
# 2018                   NaN  121487.095269           NaN            NaN
# 2019                   NaN  146886.241908           NaN            NaN
# 2020                   NaN   98515.455382           NaN            NaN
# 2021             12500.000  139038.050617  28491.375333  259274.919129
# ...

# %% [markdown]
# #### What is the total amount of the original contract status in Season

# %%
new_df2=pd.pivot_table(data=df, values ='original_amount',columns ='contract_status',index ='Season')
new_df2
# Out:
# contract_status            4          CLOSED       CREATED         POSTED
# Season
# Autumn                    NaN   94668.032433  30182.356154  247037.245900
# Spring                    NaN  141462.384750           NaN   17983.055000
# Summer                    NaN   74663.525218  25000.000000  256060.939573
# Winter           56304.152857  107570.377154  88870.551538  249853.761188

# %% [markdown]
# #### What is the total amount of the original contract type in Season

# %%
new_df2=pd.pivot_table(data=df, values ='original_amount',columns ='contract_type',index ='Season')
new_df2
# Out:
# contract_type  CON  (CONSTUCT/R)  ENT  (ENTERTAIN)       GENERAL  \
# Season
# Autumn             445593.890185               NaN  33772.391818
# Spring             384420.022697               NaN  25705.541818
# Summer             576003.060282           7593.77  45959.340274
# Winter             439787.144286               NaN  17865.361250
#
# contract_type  GS   (GEN SERV)  HUD (GEN SERV-HUD)  INS  (INSTRUCTOR)  \
# Season
# Autumn            78685.047342        36388.213529                NaN
# Spring            52872.940612       110000.000000            10000.0
# Summer            52054.293660        77925.293788             1008.1
# Winter            89796.278904        58926.560000             1500.0
#
# contract_type       IT/TECH  LS   (LEASE SVCS)  LW   (DON'T USE)  \
# Season
# Autumn                  NaN       13441.063333      80154.640000
# Spring          80000.00000       20532.320000      67422.780000
# ...

# %% [markdown]
# #### How much is the total payment difference with the type of contract in years

# %%
new_df2=pd.pivot_table(data=df, values ='Amount_difference',columns ='Year',index ='contract_type')
new_df2
# Out:
# Year                         2010          2011          2012          2013  \
# contract_type
# CON  (CONSTUCT/R)   154895.250000 -26155.413846 -14869.418125  10656.562812
# ENT  (ENTERTAIN)         0.000000           NaN           NaN           NaN
# GENERAL              -1122.102564  -2156.804737  -5093.490263  -4709.400000
# GS   (GEN SERV)       2414.324857  -2839.927246  -4445.024846  -4355.808696
# HUD (GEN SERV-HUD)            NaN           NaN           NaN           NaN
# INS  (INSTRUCTOR)        0.000000      0.000000   -550.000000   1451.200000
# IT/TECH                       NaN           NaN           NaN           NaN
# LS   (LEASE SVCS)    -6642.150000      0.000000  -3400.000000  -3638.665000
# LW   (DON'T USE)              NaN           NaN      0.000000   -328.828333
# PRO  (PRO SERVIC)        0.000000  -5483.587500  -9504.033333   1671.291765
# RISK - HR / INS               NaN           NaN           NaN           NaN
# ...

# %% [markdown]
# #### Arrange the data in ascending order based on a column Amount difference

# %%
df.sort_values('Amount_difference')
# Out:
#       contract_number                               contract_description  \
# 2995         91800082  TRANSIT OPERATIONAL MANAGEMENT SERVICES       ...
# 2741         91700236  CONSTRUCTION MANAGER AT RISK - TIGER VI       ...
# 1828         91100263  CURBSIDE RECYCLING COLLECTION PROGRAM AND SERV...
# 2105         91800139  NORTH FORK SPILLWAY & EMBANKMENT IMPROVEMENTS ...
# 1945         91800313  CMAR FOR USCC RENOVATION AND HVAC.            ...
# ...               ...                                                ...
# 2479         92200319  HENDERSON COUNTY HABITAT DODD MEADOWS FY 18-19...
# 2829         92200186  NORTH FORK SPILLWAY SOFTWARE SUBSCRIPTION - 3 ...
# 2875         92200206  ANNUAL BUS PASSES FOR ART PASSENGERS FOR 2022 ...
# 2959         91100418  FY11 DELL STORAGE & DATA CENTER SERVICES      ...
# 3095         92200174  SECURITY SERVICES FOR THE RAMADA INN CONTRACT ...
#
#      contract_status       contract_type             last_modified  \
# ...

# %% [markdown]
# #### When the Amount Difference was 0 of them vendor name & vendor city &vendor state & contract description & contract_status & contract type & original amount  &Year & month & Season

# %%
df[(df['Amount_difference'])==0][['vendor_name_x','vendor_state','vendor_city','contract_description', 'contract_status','contract_type', 'original_amount', 'Year', 'month','Season']][:8:]
# Out:
#                    vendor_name_x vendor_state vendor_city  \
# 3   BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
# 4   BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
# 5   BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
# 6   BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
# 8   BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
# 9   BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
# 13  BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
# 14  BUNCOMBE COUNTY FINANCE DEPT           NC   ASHEVILLE
#
#                                  contract_description contract_status  \
# 3   POLICE ID BUREAU- CONT SERVICES FOR FY 2014-15...          CLOSED
# 4   INTERLOCAL AGREEMENT - HOMEOWNER TAX REBATE GR...          POSTED
# 5   RADIO DISPATCHERS PER ADD. 2 TO INTERGOV'T AGR...          CLOSED
# 6   CONTINUATION OF SERVICES FOR FY 2013-14       ...          CLOSED
# 8   BUNCOMBE COUNTY JOINT UTILITY ENERGY INNOVATIO...          CLOSED
# ...

# %% [markdown]
# #### What is the year in which the largest number of contracts type ?

# %%
df[(df['contract_type']==df['contract_type'])].mode()[['Year']][:1:]
# Out:
#      Year
# 0  2021.0

# %% [markdown]
# #### What are the first ten rows of columns for the columns Year, Season, Contract Status, Contract Type, Vendor Status, Vendor City, Vendor Name, in descending order based on original amount

# %%
df.sort_values('original_amount',ascending=False)[['Year','Season','contract_status','contract_type','vendor_state','vendor_city','vendor_name_x']].head(10)
# Out:
#       Year  Season contract_status      contract_type vendor_state  \
# 2105  2021  Summer          POSTED  CON  (CONSTUCT/R)           TN
# 1318  2021  Autumn          POSTED  CON  (CONSTUCT/R)           NC
# 1881  2021  Winter          POSTED  CON  (CONSTUCT/R)           SC
# 621   2018  Spring          CLOSED  CON  (CONSTUCT/R)           NC
# 2995  2022  Winter          POSTED    GS   (GEN SERV)           TX
# 622   2022  Winter          CLOSED  CON  (CONSTUCT/R)           NC
# 2277  2019  Summer          CLOSED  CON  (CONSTUCT/R)           NC
# 267   2019  Autumn          CLOSED    GS   (GEN SERV)           IL
# 1014  2021  Summer          POSTED  PRO  (PRO SERVIC)           NC
# 959   2021  Summer          CLOSED    GS   (GEN SERV)           NC
#
#          vendor_city                               vendor_name_x
# 2105       KNOXVILLE                     PHILLIPS & JORDAN, INC.
# 1318       CHARLOTTE                       GLEESON BUILDERS, LLC
# ...

# %%
df[(df['original_amount']==df['original_amount'].max())][['Year']]
# Out:
#       Year
# 2105  2021

# %% [markdown]
# #### How many of each type of contracts are there in the most contracted year?

# %%
df[(df['Year']==2021.0)][['contract_type']].value_counts()
# Out:
# contract_type
# GS   (GEN SERV)       511
# PRO  (PRO SERVIC)     169
# CON  (CONSTUCT/R)      83
# HUD (GEN SERV-HUD)     44
# RNT  (EQUIP RENT)      10
# LS   (LEASE SVCS)       7
# IT/TECH                 6
# RISK - HR / INS         5
# dtype: int64

# %% [markdown]
# #### What are the first ten rows of columns for the columns Amount difference , Year, Season, Contract Status, Contract Type, Vendor Status, Vendor City, Vendor Name, in ascending order based on original amount

# %%
df.sort_values('original_amount')[['Amount_difference','Year','Season','contract_status','contract_type','vendor_state','vendor_city','vendor_name_x']].head(10)
# Out:
#       Amount_difference  Year  Season contract_status       contract_type  \
# 2551          -44255.68  2022  Winter          POSTED  HUD (GEN SERV-HUD)
# 1895          -10787.00  2022  Winter          POSTED     GS   (GEN SERV)
# 721           -22000.00  2022  Winter          POSTED     GS   (GEN SERV)
# 664           -96000.00  2022  Winter          POSTED     GS   (GEN SERV)
# 1974               0.00  2010  Summer          CLOSED     GS   (GEN SERV)
# 1706        -2854163.26  2022  Winter          POSTED     GS   (GEN SERV)
# 2144          -10000.00  2022  Winter          POSTED     GS   (GEN SERV)
# 2158          -44000.00  2022  Winter          POSTED     GS   (GEN SERV)
# 1674         -146603.50  2022  Winter          POSTED     GS   (GEN SERV)
# 193               -1.00  2021  Summer          POSTED   PRO  (PRO SERVIC)
#
#      vendor_state    vendor_city                         vendor_name_x
# 2551           NC      ASHEVILLE      EAGLE MARKET STREETS DEVELOPMENT
# ...

# %% [markdown]
# #### How many years has the lowest principal amount been paid?

# %%
df[(df['original_amount']==df['original_amount'].min())][['Year']].value_counts()
# Out:
# Year
# 2022    12
# 2010     2
# 2021     2
# dtype: int64

# %% [markdown]
# #### How many Season has the lowest principal amount been paid?

# %%
df[(df['original_amount']==df['original_amount'].min())][['Season']].value_counts()
# Out:
# Season
# Winter    12
# Summer     3
# Autumn     1
# dtype: int64

# %%
df['original_amount'].min()
# Out:
# 0.0

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.select_dtypes(exclude=([object])).columns
# Out:
# Index(['contract_number', 'last_modified', 'original_amount', 'revised_amount',
#        'vendor_id', 'Amount_difference', 'Year', 'month'],
#       dtype='object')

# %%
sns.kdeplot(df['original_amount'], color='m')
# Out:
# <AxesSubplot:xlabel='original_amount', ylabel='Density'>

# %%
sns.kdeplot(df['revised_amount'],color='m')
# Out:
# <AxesSubplot:xlabel='revised_amount', ylabel='Density'>

# %%
sns.kdeplot(df['Amount_difference'],color='m')
# Out:
# <AxesSubplot:xlabel='Amount_difference', ylabel='Density'>

# %%
sns.distplot(df['Year'], kde=False, bins=30, color='m')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year'>

# %%
sns.distplot(df['month'], kde=False, bins=30, color='m')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
sns.jointplot(x='Year', y='original_amount', data=df, kind='reg', height=8, color='m')

# %%
sns.jointplot(x='vendor_id', y='original_amount', data=df, kind='reg', height=8, color='m')

# %%
sns.jointplot(x='month', y='original_amount', data=df, kind='reg', height=8, color='m')

# %%
sns.jointplot(x='Year', y='revised_amount', data=df, kind='reg', height=8, color='m')

# %%
sns.jointplot(x='month', y='revised_amount', data=df, kind='reg', height=8, color='m')

# %%
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.jointplot(x='original_amount', y='revised_amount', data=df, kind='kde', cmap=cmap, height=8)
sns.jointplot(x='original_amount', y='revised_amount', data=df, kind='hex', cmap=cmap, height=8)

# %%
sns.catplot(x="contract_status", y="revised_amount", data=df, height=6, aspect=1.3, kind="swarm", hue='Season', palette='rocket')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 96.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="Year", y="original_amount", data=df, height=6, aspect=1.3, kind="swarm", hue='contract_status', palette='rocket')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 94.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(y="contract_type", x="original_amount", data=df, height=6, aspect=1.3, kind="swarm", hue='contract_status', palette='rocket')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 98.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 94.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(y="contract_type", x="Amount_difference", data=df, height=6, aspect=1.3, kind="swarm", hue='contract_status', palette='rocket')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 98.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 93.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(y="contract_type", x="revised_amount", data=df, height=6, aspect=1.3, kind="swarm", hue='contract_status', palette='rocket')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 98.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 94.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(x="contract_status", y="original_amount", data=df, height=6, aspect=1.3, kind="swarm", hue='vendor_state', palette='rocket')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 96.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="contract_status", y="revised_amount", data=df, height=6, aspect=1.3, kind="swarm", hue='vendor_state', palette='rocket')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 96.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.select_dtypes(exclude=([object])).columns
# Out:
# Index(['contract_number', 'last_modified', 'original_amount', 'revised_amount',
#        'vendor_id', 'Amount_difference', 'Year', 'month'],
#       dtype='object')

# %%
df.select_dtypes(include=([object])).columns
# Out:
# Index(['contract_description', 'contract_status', 'contract_type',
#        'vendor_name_x', 'vendor_city', 'vendor_state', 'vendor_zip_code',
#        'week_day', 'Season'],
#       dtype='object')

# %%
sns.stripplot(x="Season", y="original_amount", hue="contract_status",data=df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Season', ylabel='original_amount'>

# %%
sns.stripplot(x="week_day", y="original_amount", hue="contract_status",data=df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='week_day', ylabel='original_amount'>

# %%
sns.stripplot(y="contract_type", x="original_amount", hue="vendor_state",data=df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='original_amount', ylabel='contract_type'>

# %%
sns.stripplot(x="month", y="revised_amount", hue="contract_type",data=df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='month', ylabel='revised_amount'>

# %%
sns.stripplot(x="month", y="original_amount", hue="contract_type",data=df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='month', ylabel='original_amount'>

# %%
sns.stripplot(x="Year", y="original_amount", hue="contract_type",data=df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='original_amount'>

# %%
df.columns
# Out:
# Index(['contract_number', 'contract_description', 'contract_status',
#        'contract_type', 'last_modified', 'original_amount', 'revised_amount',
#        'vendor_id', 'vendor_name_x', 'vendor_city', 'vendor_state',
#        'vendor_zip_code', 'Amount_difference', 'Year', 'month', 'week_day',
#        'Season'],
#       dtype='object')

# %%
df.drop(['contract_number','vendor_zip_code','vendor_id','last_modified','vendor_name_x','contract_description'], axis=1, inplace=True)

# %%
df.isna().sum()/len(df)*100
# Out:
# contract_status      0.000000
# contract_type        0.000000
# original_amount      0.285896
# revised_amount       0.285896
# vendor_city          0.000000
# vendor_state         0.063532
# Amount_difference    0.285896
# Year                 0.000000
# month                0.000000
# week_day             0.000000
# Season               0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3148 entries, 0 to 3147
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   contract_status    3148 non-null   object
#  1   contract_type      3148 non-null   object
#  2   original_amount    3139 non-null   float64
#  3   revised_amount     3139 non-null   float64
#  4   vendor_city        3148 non-null   object
#  5   vendor_state       3146 non-null   object
#  6   Amount_difference  3139 non-null   float64
#  7   Year               3148 non-null   int64
#  8   month              3148 non-null   int64
#  9   week_day           3148 non-null   object
#  10  Season             3148 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 295.1+ KB

# %%
df.select_dtypes(exclude=([object])).columns
# Out:
# Index(['original_amount', 'revised_amount', 'Amount_difference', 'Year',
#        'month'],
#       dtype='object')

# %%
df.select_dtypes(include=([object])).columns
# Out:
# Index(['contract_status', 'contract_type', 'vendor_city', 'vendor_state',
#        'week_day', 'Season'],
#       dtype='object')

# %%
numerical=['original_amount', 'revised_amount', 'Amount_difference', 'Year','month']
categoriacal=['contract_status', 'contract_type', 'vendor_city', 'vendor_state','week_day', 'Season']

# %%
from sklearn.impute import SimpleImputer , KNNImputer

# %%
imputer = KNNImputer()

# %%
for fit in numerical:
    df[[fit]] = imputer.fit_transform(df[[fit]])

# %%
df.isna().sum()/len(df)*100
# Out:
# contract_status      0.000000
# contract_type        0.000000
# original_amount      0.000000
# revised_amount       0.000000
# vendor_city          0.000000
# vendor_state         0.063532
# Amount_difference    0.000000
# Year                 0.000000
# month                0.000000
# week_day             0.000000
# Season               0.000000
# dtype: float64

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
for fit in numerical:
    df[fit] = imputer.fit_transform(df[[fit]])

# %%
df.isna().sum()/len(df)*100
# Out:
# contract_status      0.000000
# contract_type        0.000000
# original_amount      0.000000
# revised_amount       0.000000
# vendor_city          0.000000
# vendor_state         0.063532
# Amount_difference    0.000000
# Year                 0.000000
# month                0.000000
# week_day             0.000000
# Season               0.000000
# dtype: float64

# %%
df.drop(['vendor_city','week_day','Season','vendor_state'], axis=1, inplace=True)

# %%
categoriacal
# Out:
# ['contract_status',
#  'contract_type',
#  'vendor_city',
#  'vendor_state',
#  'week_day',
#  'Season']

# %%
df = pd.get_dummies(df, columns=['contract_status','contract_type'], drop_first=True)

# %%
df.columns
# Out:
# Index(['original_amount', 'revised_amount', 'Amount_difference', 'Year',
#        'month', 'contract_status_CLOSED', 'contract_status_CREATED',
#        'contract_status_POSTED', 'contract_type_ENT  (ENTERTAIN)',
#        'contract_type_GENERAL', 'contract_type_GS   (GEN SERV)',
#        'contract_type_HUD (GEN SERV-HUD)', 'contract_type_INS  (INSTRUCTOR)',
#        'contract_type_IT/TECH', 'contract_type_LS   (LEASE SVCS)',
#        'contract_type_LW   (DON'T USE)', 'contract_type_PRO  (PRO SERVIC)',
#        'contract_type_RISK - HR / INS', 'contract_type_RNT  (EQUIP RENT)'],
#       dtype='object')

# %%
df.shape
# Out:
# (3148, 19)

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_scaled = scaler.fit_transform(df)

# %%
scores = []
for i in range(1, 100):
    model = KMeans(n_clusters=i)
    model.fit(df_scaled)
    scores.append(model.inertia_)
plt.plot(range(1, 100), scores)
plt.title("Elbow Method")
plt.xlabel("num of clusters")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
model = KMeans(n_clusters=20)
clusters = model.fit_predict(df)
clusters
# Out:
# array([ 7, 12, 12, ...,  0, 12, 12])

# %%
centroids = model.cluster_centers_
centroids
# Out:
# array([[ 1.36134779e+05,  1.76134657e+05, -3.99998780e+04,
#          2.01836455e+03,  6.53177258e+00,  7.02341137e-01,
#          2.67558528e-02,  2.67558528e-01, -8.67361738e-19,
#          3.67892977e-02,  4.78260870e-01,  6.35451505e-02,
#         -1.73472348e-18,  3.34448161e-03,  2.00668896e-02,
#          3.01003344e-02,  1.50501672e-01,  1.00334448e-02,
#          6.68896321e-03],
#        [ 4.92087388e+06,  3.90500612e+07, -3.41291873e+07,
#          2.02200000e+03,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 3.49280000e+07,  4.01672000e+07, -5.23920000e+06,
#          2.02100000e+03,  8.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
# ...

# %%
import joblib

# %%
joblib.dump(model, 'kmeans_model.h5')
joblib.dump(scaler, 'kmeans_scaler.h5')
# Out:
# ['kmeans_scaler.h5']

# %%
df.columns
# Out:
# Index(['original_amount', 'revised_amount', 'Amount_difference', 'Year',
#        'month', 'contract_status_CLOSED', 'contract_status_CREATED',
#        'contract_status_POSTED', 'contract_type_ENT  (ENTERTAIN)',
#        'contract_type_GENERAL', 'contract_type_GS   (GEN SERV)',
#        'contract_type_HUD (GEN SERV-HUD)', 'contract_type_INS  (INSTRUCTOR)',
#        'contract_type_IT/TECH', 'contract_type_LS   (LEASE SVCS)',
#        'contract_type_LW   (DON'T USE)', 'contract_type_PRO  (PRO SERVIC)',
#        'contract_type_RISK - HR / INS', 'contract_type_RNT  (EQUIP RENT)'],
#       dtype='object')

# %%
df.shape
# Out:
# (3148, 19)

# %%
model.predict(scaler.transform([[10000,10000,0,2020,5,0,0,1,0,0,1,0,0,0,1,0,0,0,0]]))
# Out:
# array([12])

# %%
df['clusters']= clusters

# %%
df.groupby('clusters').describe()[['original_amount','revised_amount','Amount_difference','Year' ]].transpose()
# Out:
# clusters                            0            1           2             3   \
# original_amount   count     299.000000         1.00         1.0  1.000000e+01
#                   mean   136134.778978   4920873.88  34928000.0  4.123717e+06
#                   std     65456.359400          NaN         NaN  3.889624e+05
#                   min         0.000000   4920873.88  34928000.0  3.577798e+06
#                   25%     95000.000000   4920873.88  34928000.0  3.833488e+06
#                   50%    126820.000000   4920873.88  34928000.0  4.089080e+06
#                   75%    188481.150000   4920873.88  34928000.0  4.385864e+06
#                   max    299397.000000   4920873.88  34928000.0  4.749345e+06
# revised_amount    count     299.000000         1.00         1.0  1.000000e+01
#                   mean   176134.656941  39050061.20  40167200.0  4.103950e+06
#                   std     64953.363279          NaN         NaN  3.483526e+05
# ...

# %%
sns.stripplot(y='Year',x='clusters',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='clusters', ylabel='Year'>

# %%
sns.stripplot(y='Amount_difference',x='clusters',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='clusters', ylabel='Amount_difference'>

# %%
sns.stripplot(y='revised_amount',x='clusters',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='clusters', ylabel='revised_amount'>

# %%
sns.stripplot(y='original_amount',x='clusters',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='clusters', ylabel='original_amount'>
